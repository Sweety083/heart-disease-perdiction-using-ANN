# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LeakyReLU
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# %%
data = pd.read_csv('heart.csv')
data.head()
# Out:
#    age  sex  chest_pain_type  Resting_Blood_Pressure  Serum_Cholestrol  \
# 0   63    1                3                     145               233
# 1   37    1                2                     130               250
# 2   41    0                1                     130               204
# 3   56    1                1                     120               236
# 4   57    0                0                     120               354
#
#    Diabetes  restecg  thalach  exang  oldpeak  slope  ca  thalassemia  target
# 0         1        0      150      0      2.3      0   0            1       1
# 1         0        1      187      0      3.5      0   0            2       1
# 2         0        0      172      0      1.4      2   0            2       1
# 3         0        1      178      0      0.8      2   0            2       1
# 4         0        1      163      1      0.6      2   0            2       1

# %%
data.describe()
# Out:
#                age          sex  chest_pain_type  Resting_Blood_Pressure  \
# count  1212.000000  1212.000000      1212.000000             1212.000000
# mean     54.366337     0.683168         0.966997              131.623762
# std       9.070845     0.465433         1.030773               17.516406
# min      29.000000     0.000000         0.000000               94.000000
# 25%      47.000000     0.000000         0.000000              120.000000
# 50%      55.000000     1.000000         1.000000              130.000000
# 75%      61.000000     1.000000         2.000000              140.000000
# max      77.000000     1.000000         3.000000              200.000000
#
#        Serum_Cholestrol     Diabetes      restecg      thalach        exang  \
# count       1212.000000  1212.000000  1212.000000  1212.000000  1212.000000
# mean         246.264026     0.148515     0.528053   149.646865     0.326733
# std           51.766511     0.355756     0.525208    22.876772     0.469212
# min          126.000000     0.000000     0.000000    71.000000     0.000000
# 25%          211.000000     0.000000     0.000000   133.000000     0.000000
# 50%          240.000000     0.000000     1.000000   153.000000     0.000000
# 75%          275.000000     0.000000     1.000000   166.000000     1.000000
# max          564.000000     1.000000     2.000000   202.000000     1.000000
#
#            oldpeak        slope           ca  thalassemia       target
# count  1212.000000  1212.000000  1212.000000  1212.000000  1212.000000
# mean      1.039604     1.399340     0.729373     2.313531     0.544554
# std       1.159636     0.615462     1.021339     0.611518     0.498217
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000     2.000000     0.000000
# 50%       0.800000     1.000000     0.000000     2.000000     1.000000
# 75%       1.600000     2.000000     1.000000     3.000000     1.000000
# max       6.200000     2.000000     4.000000     3.000000     1.000000

# %%
data['ID'] = data.index  # Add an ID column
# Rearrange columns to place ID as the first column
cols = ['ID'] + [col for col in data.columns if col != 'ID']
data = data[cols]

# %%
data.head()
# Out:
#    ID  age  sex  chest_pain_type  Resting_Blood_Pressure  Serum_Cholestrol  \
# 0   0   63    1                3                     145               233
# 1   1   37    1                2                     130               250
# 2   2   41    0                1                     130               204
# 3   3   56    1                1                     120               236
# 4   4   57    0                0                     120               354
#
#    Diabetes  restecg  thalach  exang  oldpeak  slope  ca  thalassemia  target
# 0         1        0      150      0      2.3      0   0            1       1
# 1         0        1      187      0      3.5      0   0            2       1
# 2         0        0      172      0      1.4      2   0            2       1
# 3         0        1      178      0      0.8      2   0            2       1
# 4         0        1      163      1      0.6      2   0            2       1

# %%
data.isnull().any()
# Out:
# ID                        False
# age                       False
# sex                       False
# chest_pain_type           False
# Resting_Blood_Pressure    False
# Serum_Cholestrol          False
# Diabetes                  False
# restecg                   False
# thalach                   False
# exang                     False
# oldpeak                   False
# slope                     False
# ca                        False
# thalassemia               False
# target                    False
# dtype: bool

# %%
X = data.iloc[:, 1:-1].values 
y = data["target"].values

# %%
X_train, X_test, y_train, y_test, ids_train, ids_test = train_test_split(X, y, data['ID'], test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Create a Sequential model
classifier = Sequential()

# First hidden layer with Leaky ReLU
classifier.add(Dense(units = 8, input_dim = 13, kernel_initializer = "uniform"))
classifier.add(LeakyReLU(alpha=0.01))  # alpha controls the slope of the negative part

# Second hidden layer with Leaky ReLU
classifier.add(Dense(units = 14, kernel_initializer = "uniform"))
classifier.add(LeakyReLU(alpha=0.01))  # alpha controls the slope of the negative part

# Output layer with Sigmoid activation
classifier.add(Dense(units = 1, kernel_initializer = "uniform", activation='sigmoid'))

# Compile the model
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train , y_train , batch_size = 8 ,epochs = 100 )
# Out:
# Epoch 1/100
# 122/122 [==============================] - 1s 2ms/step - loss: 0.6660 - accuracy: 0.7265
# Epoch 2/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8473
# Epoch 3/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3551 - accuracy: 0.8576
# Epoch 4/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8658
# Epoch 5/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.3298 - accuracy: 0.8658
# Epoch 6/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8679
# Epoch 7/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3151 - accuracy: 0.8813
# Epoch 8/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3087 - accuracy: 0.8844
# Epoch 9/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.3045 - accuracy: 0.8906
# Epoch 10/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2996 - accuracy: 0.8896
# Epoch 11/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2944 - accuracy: 0.8885
# Epoch 12/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2903 - accuracy: 0.8865
# Epoch 13/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.8947
# Epoch 14/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2810 - accuracy: 0.9009
# Epoch 15/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2761 - accuracy: 0.9051
# Epoch 16/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2717 - accuracy: 0.9051
# Epoch 17/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.9092
# Epoch 18/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.9102
# Epoch 19/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2592 - accuracy: 0.9143
# Epoch 20/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2570 - accuracy: 0.9164
# Epoch 21/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.9195
# Epoch 22/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2457 - accuracy: 0.9195
# Epoch 23/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2420 - accuracy: 0.9205
# Epoch 24/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.9205
# Epoch 25/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2331 - accuracy: 0.9216
# Epoch 26/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2303 - accuracy: 0.9236
# Epoch 27/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2265 - accuracy: 0.9257
# Epoch 28/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2280 - accuracy: 0.9247
# Epoch 29/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2203 - accuracy: 0.9298
# Epoch 30/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2172 - accuracy: 0.9340
# Epoch 31/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2147 - accuracy: 0.9298
# Epoch 32/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2121 - accuracy: 0.9278
# Epoch 33/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.2097 - accuracy: 0.9257
# Epoch 34/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2062 - accuracy: 0.9319
# Epoch 35/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2036 - accuracy: 0.9319
# Epoch 36/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.2008 - accuracy: 0.9319
# Epoch 37/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9319
# Epoch 38/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.9329
# Epoch 39/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.9360
# Epoch 40/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1885 - accuracy: 0.9360
# Epoch 41/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1851 - accuracy: 0.9422
# Epoch 42/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 0.9432
# Epoch 43/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.9370
# Epoch 44/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1790 - accuracy: 0.9422
# Epoch 45/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9422
# Epoch 46/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1720 - accuracy: 0.9463
# Epoch 47/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1694 - accuracy: 0.9422
# Epoch 48/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.1693 - accuracy: 0.9401
# Epoch 49/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1640 - accuracy: 0.9453
# Epoch 50/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.1629 - accuracy: 0.9474
# Epoch 51/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1591 - accuracy: 0.9422
# Epoch 52/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.9432
# Epoch 53/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9443
# Epoch 54/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1502 - accuracy: 0.9453
# Epoch 55/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.1471 - accuracy: 0.9484
# Epoch 56/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.9463
# Epoch 57/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.1429 - accuracy: 0.9484
# Epoch 58/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1402 - accuracy: 0.9453
# Epoch 59/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1353 - accuracy: 0.9484
# Epoch 60/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9494
# Epoch 61/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1293 - accuracy: 0.9515
# Epoch 62/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1282 - accuracy: 0.9525
# Epoch 63/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9536
# Epoch 64/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.9598
# Epoch 65/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1195 - accuracy: 0.9628
# Epoch 66/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1189 - accuracy: 0.9577
# Epoch 67/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1160 - accuracy: 0.9608
# Epoch 68/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9628
# Epoch 69/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1127 - accuracy: 0.9628
# Epoch 70/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.9618
# Epoch 71/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.9659
# Epoch 72/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9649
# Epoch 73/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9628
# Epoch 74/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9618
# Epoch 75/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9649
# Epoch 76/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9639
# Epoch 77/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0928 - accuracy: 0.9639
# Epoch 78/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9649
# Epoch 79/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0912 - accuracy: 0.9639
# Epoch 80/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9659
# Epoch 81/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9649
# Epoch 82/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0876 - accuracy: 0.9628
# Epoch 83/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.9639
# Epoch 84/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0856 - accuracy: 0.9659
# Epoch 85/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9628
# Epoch 86/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 0.9670
# Epoch 87/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9639
# Epoch 88/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0817 - accuracy: 0.9659
# Epoch 89/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0810 - accuracy: 0.9649
# Epoch 90/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9659
# Epoch 91/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0789 - accuracy: 0.9628
# Epoch 92/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9659
# Epoch 93/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9670
# Epoch 94/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9659
# Epoch 95/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0759 - accuracy: 0.9649
# Epoch 96/100
# 122/122 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9670
# Epoch 97/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9670
# Epoch 98/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9670
# Epoch 99/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.9680
# Epoch 100/100
# 122/122 [==============================] - 0s 2ms/step - loss: 0.0737 - accuracy: 0.9649

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
predictions_df = pd.DataFrame({
    'ID': ids_test,
    'Actual': y_test,
    'Predicted': y_pred.flatten()
})

# %%
print("Predictions:\n", predictions_df)
# Out:
# Predictions:
#          ID  Actual  Predicted
# 198    198       0      False
# 1009  1009       1       True
# 55      55       1       True
# 743    743       1       True
# 907    907       0      False
# ...    ...     ...        ...
# 642    642       1       True
# 1042  1042       1       True
# 580    580       0      False
# 995    995       1       True
# 187    187       0      False
#
# [243 rows x 3 columns]

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[100,   2],
#        [  4, 137]], dtype=int64)

# %%
accuracy = (cm[0][0]+cm[1][1])/(cm[0][1] + cm[1][0] +cm[0][0] +cm[1][1])
print(accuracy*100)
# Out:
# 97.53086419753086

# %% [markdown]
# ## **Comparative Analysis**

# %%
from keras.layers import LeakyReLU
from sklearn.metrics import f1_score, confusion_matrix

def build_model(activation):
    model = Sequential()
    model.add(Dense(units=8, input_dim=13, kernel_initializer='uniform'))
    
    # Applying Leaky ReLU separately as it needs special handling
    if activation == 'leaky_relu':
        model.add(LeakyReLU(alpha=0.01))  
    else:
        model.add(Dense(units=8, activation=activation))
    
    model.add(Dense(units=14, activation=activation, kernel_initializer='uniform'))
    model.add(Dense(units=1, activation='sigmoid', kernel_initializer='uniform'))  # Sigmoid for binary classification
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Define the activation functions to test
activations = ['relu', 'tanh', 'sigmoid', 'leaky_relu']
results = {}

for activation in activations:
    print(f"\nTesting with Activation Function: {activation}")
    model = build_model(activation)
    
    # Train the model
    model.fit(X_train, y_train, epochs=100, batch_size=8, verbose=0)
    
    # Make predictions
    y_pred = model.predict(X_test)
    y_pred = (y_pred > 0.5).astype(int).flatten()  # Binarize predictions
    
    # Calculate all metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    # Store results
    results[activation] = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }
    
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
# Out:
# Testing with Activation Function: relu
# 8/8 [==============================] - 0s 2ms/step
# Accuracy: 0.9218
# Precision: 0.9236
# Recall: 0.9433
# F1 Score: 0.9333
#
# Testing with Activation Function: tanh
# 8/8 [==============================] - 0s 2ms/step
# Accuracy: 0.9506
# Precision: 0.9574
# Recall: 0.9574
# F1 Score: 0.9574
#
# Testing with Activation Function: sigmoid
# 8/8 [==============================] - 0s 1ms/step
# Accuracy: 0.9177
# Precision: 0.9172
# Recall: 0.9433
# F1 Score: 0.9301
#
# Testing with Activation Function: leaky_relu
# 8/8 [==============================] - 0s 2ms/step
# Accuracy: 0.9671
# Precision: 0.9854
# Recall: 0.9574
# F1 Score: 0.9712

# %%
# Print the results for each activation function
print("\nComparative Analysis of Activation Functions:")
for activation, metrics in results.items():
    print(f"Activation: {activation.capitalize()} | Accuracy: {metrics['accuracy']:.4f} | Precision: {metrics['precision']:.4f} | Recall: {metrics['recall']:.4f} | F1 Score: {metrics['f1_score']:.4f}")
# Out:
# Comparative Analysis of Activation Functions:
# Activation: Relu | Accuracy: 0.9218 | Precision: 0.9236 | Recall: 0.9433 | F1 Score: 0.9333
# Activation: Tanh | Accuracy: 0.9506 | Precision: 0.9574 | Recall: 0.9574 | F1 Score: 0.9574
# Activation: Sigmoid | Accuracy: 0.9177 | Precision: 0.9172 | Recall: 0.9433 | F1 Score: 0.9301
# Activation: Leaky_relu | Accuracy: 0.9671 | Precision: 0.9854 | Recall: 0.9574 | F1 Score: 0.9712

# %%
import matplotlib.pyplot as plt

activations_list = list(results.keys())
accuracy_values = [metrics['accuracy'] for metrics in results.values()]
precision_values = [metrics['precision'] for metrics in results.values()]
recall_values = [metrics['recall'] for metrics in results.values()]
f1_values = [metrics['f1_score'] for metrics in results.values()]

# Plot each metric
plt.figure(figsize=(12, 8))
plt.plot(activations_list, accuracy_values, label="Accuracy", marker='o')
plt.plot(activations_list, precision_values, label="Precision", marker='o')
plt.plot(activations_list, recall_values, label="Recall", marker='o')
plt.plot(activations_list, f1_values, label="F1 Score", marker='o')
plt.xlabel("Activation Function")
plt.ylabel("Score")
plt.title("Activation Function Comparison: Accuracy, Precision, Recall, and F1 Score")
plt.legend()
plt.show()

# %%
# Predict on the training set
y_train_pred = classifier.predict(X_train)
y_train_pred = (y_train_pred > 0.5)

# Generate the confusion matrix for the training set
cm_train = confusion_matrix(y_train, y_train_pred)
print("Confusion Matrix for Training Set:\n", cm_train)
# Out:
# 31/31 [==============================] - 0s 2ms/step
# Confusion Matrix for Training Set:
#  [[448   2]
#  [ 28 491]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix for the training set
cm_train = confusion_matrix(y_train, y_train_pred)

# Plot the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
